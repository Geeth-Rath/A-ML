# %% [markdown]
# <a href="https://colab.research.google.com/github/Geeth-Rath/A-ML/blob/main/258417X_finalExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
## Social_Network_Ads purchase dataset is named as ads.csv

# %%
df= pd.read_csv('ads.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19          19,000           0
# 1    15810944    Male   35          20,000           0
# 2    15668575  Female   26          43,000           0
# 3    15603246  Female   27          57,000           0
# 4    15804002    Male   19          76,000           0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46          41,000           1
# 396  15706071    Male   51          23,000           1
# 397  15654296  Female   50          20,000           1
# 398  15755018    Male   36          33,000           0
# 399  15594041  Female   49          36,000           1
#
# [400 rows x 5 columns]

# %%
df.describe()
# Out:
#             User ID         Age   Purchased
# count  4.000000e+02  400.000000  400.000000
# mean   1.569154e+07   37.655000    0.357500
# std    7.165832e+04   10.482877    0.479864
# min    1.556669e+07   18.000000    0.000000
# 25%    1.562676e+07   29.750000    0.000000
# 50%    1.569434e+07   37.000000    0.000000
# 75%    1.575036e+07   46.000000    1.000000
# max    1.581524e+07   60.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User ID           400 non-null    int64
#  1   Gender            400 non-null    object
#  2   Age               400 non-null    int64
#  3    EstimatedSalary  400 non-null    object
#  4   Purchased         400 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 15.8+ KB

# %%
df= pd.read_csv('ObesityDataSet.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19          19,000           0
# 1    15810944    Male   35          20,000           0
# 2    15668575  Female   26          43,000           0
# 3    15603246  Female   27          57,000           0
# 4    15804002    Male   19          76,000           0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46          41,000           1
# 396  15706071    Male   51          23,000           1
# 397  15654296  Female   50          20,000           1
# 398  15755018    Male   36          33,000           0
# 399  15594041  Female   49          36,000           1
#
# [400 rows x 5 columns]

# %%
df.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
df.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46          41,000           1
# 396  15706071    Male   51          23,000           1
# 397  15654296  Female   50          20,000           1
# 398  15755018    Male   36          33,000           0
# 399  15594041  Female   49          36,000           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.315964     1.701620    86.586035     2.418986     2.685651
# std       6.357078     0.093368    26.191163     0.533996     0.778079
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      20.000000     1.630000    65.470000     2.000000     2.660000
# 50%      23.000000     1.700000    83.000000     2.390000     3.000000
# 75%      26.000000     1.770000   107.430000     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008053     1.010313     0.657861
# std       0.612950     0.850613     0.608926
# min       1.000000     0.000000     0.000000
# 25%       1.585000     0.125000     0.000000
# 50%       2.000000     1.000000     0.625000
# ...

# %%
duplicate_count = df.duplicated().sum()

# %%
print(duplicate_count)
# Out:
# 24

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates.to_csv('ObesityDataSet_no_duplicates.csv', index=False)

# %%
df_no_duplicates
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0     Female   21    1.62   64.00                            yes   no   2.0
# 1     Female   21    1.52   56.00                            yes   no   3.0
# 2       Male   23    1.80   77.00                            yes   no   2.0
# 3       Male   27    1.80   87.00                             no   no   3.0
# 4       Male   22    1.78   89.80                             no   no   2.0
# ...      ...  ...     ...     ...                            ...  ...   ...
# 2106  Female   21    1.71  131.41                            yes  yes   3.0
# 2107  Female   22    1.75  133.74                            yes  yes   3.0
# 2108  Female   23    1.75  133.69                            yes  yes   3.0
# 2109  Female   24    1.74  133.35                            yes  yes   3.0
# 2110  Female   24    1.74  133.47                            yes  yes   3.0
#
# ...

# %%
df_modified =  pd.read_csv('ObesityDataSet_no_duplicates.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

df = pd.read_csv('ObesityDataSet_no_duplicates.csv')

categorical_cols = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC',
                    'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']

le = LabelEncoder()
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

correlation_matrix = df.corr(numeric_only=True)
correlation_abs = correlation_matrix.abs()

for i in correlation_abs.columns:
    correlation_abs.loc[i, i] = 0
max_corr_pair = correlation_abs.unstack().sort_values(ascending=False).idxmax()
max_corr_value = correlation_abs.loc[max_corr_pair]

correlations_52 = {
    "SCC_Weight": df["SCC"].corr(df["Weight"]),
    "FAVC_Family": df["FAVC"].corr(df["family_history_with_overweight"]),
    "CH2O_FCVC": df["CH2O"].corr(df["FCVC"]),
    "FAF_Weight": df["FAF"].corr(df["Weight"])
}

spearman_corr, _ = spearmanr(df["Height"], df["Weight"])

# %%
spearman_corr
# Out:
# np.float64(0.45522349001504003)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def count_outliers(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] < lower) | (df[column] > upper)].shape[0]

outliers_height = count_outliers("Height")
outliers_weight = count_outliers("Weight")

results_df = pd.DataFrame({
    "Outliers in Height": [outliers_height],
    "Outliers in Weight": [outliers_weight],
})

print("Outliers:")
display(results_df)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(y=df["Height"])
plt.title("Boxplot of Height")

plt.subplot(1, 2, 2)
sns.boxplot(y=df["Weight"])
plt.title("Boxplot of Weight")

plt.tight_layout()
plt.show()
# Out:
# Outliers:
#    Outliers in Height  Outliers in Weight
# 0                   0                   1

# %%
X = df[["Height"]]
y = df["Weight"]

model = LinearRegression()
model.fit(X, y)

slope = model.coef_[0]
intercept = model.intercept_

slope, intercept
# Out:
# (np.float64(128.24006806754113), np.float64(-131.48491052634307))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

models = {
    "Linear Regression": LinearRegression(),
}

results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    results[name] = {
        "Mean Squared Error": mean_squared_error(y_test, y_pred),
        "R-squared": r2_score(y_test, y_pred)
    }

# %%
results_df = pd.DataFrame.from_dict(results, orient='index')
print("Model Evaluation Results:")
display(results_df)
# Out:
# Model Evaluation Results:
#                    Mean Squared Error  R-squared
# Linear Regression          556.144216   0.199637
